// %% [markdown]
// # Export Network as Touchstone File
//
// This is the **rust-rf** edition of the upstream scikit-rf notebook. It demonstrates
// loading and exporting Touchstone data with explicit Result handling. Rust examples use typed values and explicit `Result` handling.
//
// The original notebook contained 2 Python code cells. They have been
// replaced by a compact, executable Rust workflow instead of retaining stale Python syntax.
// The copied data files and figures remain beside the notebook for extending the example.

// %% [markdown]
// ## Kernel setup
//
// The first cell adds the local crate and the numerical types used by the example.

// %%
:dep rust-rf = { path = "../../../.." }
:dep ndarray = "0.17.2"
:dep num-complex = "0.4.6"

// %% [markdown]
// ## Example

// %%
use rust_rf::data::DATA;

let network = DATA.ntwk1().expect("the embedded Touchstone network should load");
let output = std::env::temp_dir().join("rust-rf-notebook.s2p");
network
    .write_touchstone(&output)
    .expect("the network should be exported");
let restored = rust_rf::Network::read_touchstone(&output)
    .expect("the exported network should be readable");
std::fs::remove_file(&output).expect("the temporary Touchstone file should be removed");

println!("round-tripped {} frequency points", restored.frequency_points());

// %% [markdown]
// ## Rust API used
//
// - `Network::read_touchstone`
// - `Network::write_touchstone`
// - `io`
//
// The complete crate reference is generated from the Rust source with
// `cargo doc --all-features --open`. See `PORTING_MAP.md` at the repository root for
// the detailed upstream-to-Rust coverage map.

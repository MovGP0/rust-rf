// %% [markdown]
// # Export Network Set as MDIF File
//
// This is the **rust-rf** edition of the upstream scikit-rf notebook. It demonstrates
// collecting compatible networks and calculating set statistics. Rust examples use typed values and explicit `Result` handling.
//
// The original notebook contained 2 Python code cells. They have been
// replaced by a compact, executable Rust workflow instead of retaining stale Python syntax.
// The copied data files and figures remain beside the notebook for extending the example.

// %% [markdown]
// ## Kernel setup
//
// The first cell adds the local crate and the numerical types used by the example.

// %%
:dep rust-rf = { path = "../../../.." }
:dep ndarray = "0.17.2"
:dep num-complex = "0.4.6"

// %% [markdown]
// ## Example

// %%
use rust_rf::NetworkSet;
use rust_rf::data::DATA;

let first = DATA.ntwk1().expect("the embedded network should load");
let mut second = first.clone();
second.name = Some("second measurement".to_owned());
let set = NetworkSet::new(vec![first, second], Some("measurements".to_owned()))
    .expect("the networks should be compatible");
let mean = set.mean_s().expect("the mean network should be available");

println!("{} networks; mean has {} ports", set.len(), mean.ports());

// %% [markdown]
// ## Rust API used
//
// - `NetworkSet`
// - `NetworkSet::mean_s`
// - `NetworkSet::std_s`
//
// The complete crate reference is generated from the Rust source with
// `cargo doc --all-features --open`. See `PORTING_MAP.md` at the repository root for
// the detailed upstream-to-Rust coverage map.
